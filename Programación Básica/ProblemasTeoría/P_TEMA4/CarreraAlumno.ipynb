# %% [markdown]
# # EJERCICIO CARRERA: TEMA 4
#
#
# Normas:
# *	El  fichero entregado debe ser este mismo fichero (extensión .ipynb)
# *	Debéis subir el ejercicio al taller de Moodle
# *	No olvidéis indicar al inicio de cada fichero vuestro nombre mediante un comentario Python
# *	El nombre del archivo entregado debe ser CarreraXXX.ipynb (donde XXX son vuestras iniciales)

# %% [markdown]
# ## Ejercicio 1
# Vamos a recrear el cuento de la Liebre y la Tortuga haciendo que el programa que debemos implementar, simule una carrera entre ellas.
#
# Para darle ventaja a la Tortuga, esta saldrá desde la casilla 10 y la Liebre saldrá de la casilla 0. Ganará quien llegue primero a la casilla 30.
#
# Resulta que la tortuga va mas lenta, pero segura y su dado solamente saca valores entre 1 y 2. En cambio, la liebre es más rápida, pero también más perezosa, por lo tanto su dado sacará valores entre 0 y 6.
#
# Para que el ejercicio sea más fácil, se pide implementar las siguientes funciones:
#
# __Función tirarDado__: Esta función recibe como parámetro quien tira el dado:
# - Si el tirador es 'tortuga' la función tiene que devolver un número entero entre 1 y 2 y mostrar el mensaje "La tortuga ha sacado un [X].
# - Si el tirador es 'liebre' la función tiene que devolver un número enero entre 0 y 6 y mostrar el mensaje "La liebre ha sacado un [X].
# - Dentro de la función utilizar correctamente la función random.randint()
#
# __Función getJugarOtraVez__:    La función pregunta si quieres jugar otra vez y espera una respuesta, que debe ser S o N (en mayúscula o en minúscula, da igual). La función sigue preguntando mientras el usuario no introduzca una entrada válida.
#
# La función devuelve True si el usuario introduce 's' o 'S', y False si introduce 'n' o 'N'.
#
# __Función simularCarrera__: Esta función se ejecuta en bucle hasta que uno de los dos participantes llega a la casilla 30. Para cada ronda:
# - En primer lugar tira la tortuga y se debe llamar correctamente a la función tirarDado con el valor del parámetro correspondiente.
# - En segundo lugar tira la liebre y también se debe llamar correctamente a la función tirarDado con el parámetro correspondiente
# - Finalmente se hace la llamada a mostrarEstado para visualizar el estado de la partida
#
# Cuando uno de los dos participantes llegue a 30 o más, se acaba el juego y se muestra por pantalla el ganador o el empate.
#  - Si gana la tortuga se mostrará "Ha ganado la tortuga"
#  - Si gana la liebre se mostrará "Ha ganado la liebre"
#  - Si quedan empatados se mostrará "La liebre y la tortuga han empatado"

# %%
import random

def mostrarEstado(posicionLiebre, posicionTortuga, numRonda):
    if(posicionLiebre > posicionTortuga):
        print('Estamos en la ronda ',numRonda,' y va ganando la liebre')
    elif(posicionLiebre < posicionTortuga):
        print('Estamos en la ronda ',numRonda,' y va ganando la tortuga')
    else:
        print('Estamos en la ronda ', numRonda,' y la liebre y la tortuga están en la misma casilla')
        
    print('Posición Liebre ', posicionLiebre, '- Posición Tortuga ', posicionTortuga, '\n')

#Implementa aqui la función tirarDado

#Implementa aqui la función getJugarOtraVez
    
#Acaba de implementar aquí la función simularCarrera

def simularCarrera():
#Inicializa las variables
    meta =
    posicionTortuga =
    posicionLiebre =
    numRonda =
    
    #Haz el bucle de la carrera
    
    #Muestra por pantalla el resultado
    

#programa principal
while True:
    simularCarrera()
    if getJugarOtraVez()==False:
        break

print('Fin de la simulación')

# %% [markdown]
# # Ejemplo de salida
# <pre>
# La tortuga ha sacado un  1
# La liebre ha sacado un  6
# Estamos en la ronda  1  y va ganando la tortuga
# Posición Liebre  6 - Posición Tortuga  11
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  6
# Estamos en la ronda  2  y la liebre y la tortuga están en la misma casilla
# Posición Liebre  12 - Posición Tortuga  12
#
# La tortuga ha sacado un  2
# La liebre ha sacado un  2
# Estamos en la ronda  3  y la liebre y la tortuga están en la misma casilla
# Posición Liebre  14 - Posición Tortuga  14
#
# La tortuga ha sacado un  2
# La liebre ha sacado un  0
# Estamos en la ronda  4  y va ganando la tortuga
# Posición Liebre  14 - Posición Tortuga  16
#
# La tortuga ha sacado un  2
# La liebre ha sacado un  3
# Estamos en la ronda  5  y va ganando la tortuga
# Posición Liebre  17 - Posición Tortuga  18
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  2
# Estamos en la ronda  6  y la liebre y la tortuga están en la misma casilla
# Posición Liebre  19 - Posición Tortuga  19
#
# La tortuga ha sacado un  2
# La liebre ha sacado un  1
# Estamos en la ronda  7  y va ganando la tortuga
# Posición Liebre  20 - Posición Tortuga  21
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  0
# Estamos en la ronda  8  y va ganando la tortuga
# Posición Liebre  20 - Posición Tortuga  22
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  0
# Estamos en la ronda  9  y va ganando la tortuga
# Posición Liebre  20 - Posición Tortuga  23
#
# La tortuga ha sacado un  2
# La liebre ha sacado un  2
# Estamos en la ronda  10  y va ganando la tortuga
# Posición Liebre  22 - Posición Tortuga  25
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  0
# Estamos en la ronda  11  y va ganando la tortuga
# Posición Liebre  22 - Posición Tortuga  26
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  3
# Estamos en la ronda  12  y va ganando la tortuga
# Posición Liebre  25 - Posición Tortuga  27
#
# La tortuga ha sacado un  1
# La liebre ha sacado un  5
# Estamos en la ronda  13  y va ganando la liebre
# Posición Liebre  30 - Posición Tortuga  28
#
# Ha ganado la Liebre
# Desea jugar otra vez (s/n)
# </pre>
