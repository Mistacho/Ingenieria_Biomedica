# %% [markdown]
# # EJERCICIO COLORES: REPASO TEMAS 1, 2, 3 Y 4
#
# Si se pide corrección colaborativa:
# *	El  fichero entregado debe ser este mismo fichero (extensión .ipynb)
# *	Debéis subir el ejercicio al taller de Moodle
# *	No olvidéis indicar al inicio de cada fichero vuestro nombre mediante un comentario Python
# *	El nombre del archivo entregado debe ser LadronXXX.ipynb (donde XXX son vuestras iniciales)

# %% [markdown]
# Escribe un programa que permita a un usuario jugar n veces al juego 'Adivina qué color estoy pensando' .
#
# Cuando comience el programa, el juego preguntará cuántas rondas se desean jugar. El programa solo debe aceptar un número mayor que 0.
#
# Cada ronda del juego consiste en que el ordenador 'piensa' un color y pide al usuario que lo adivine. El jugador sigue intentándolo hasta que consigue adivinarlo, mientras se van contabilizando los intentos que necesita para adivinarlo. El programa debe además controlar que el usuario introduce cada vez un color válido. Si se equivoca, el programa debe volver a pedirle que introduzca el color, y no lo contará como intento.
#
# Cuando acaba el juego (todas las rondas), si el jugador tiene un número medio de intentos menor que 3, gana, si es mayor que 3, pierde, y si el número es = a 3, se asume que es un empate.
#
# Para la selección de color por parte del ordenador podéis utilizar el siguiente fragmento de código:
#
# import random
# colorOrd=random.choice(['rojo','marino','amarillo','verde','rosa'])
#
# Una vez implementado el juego, modulariza el código mediante funciones. Al menos, deben definirse las siguientes funciones:
# *	dameNumRondas()# devuelve un entero válido que indica el número de rondas que el usuario desea jugar
# *	dameColorUsuario() #pide al usuario un color, y se lo sigue pidiendo hasta que el usuario introduzca un color válido
# *	ejecutaRondas(n) #ejecuta el número de rondas que se pasa como parámetro, y devuelve el número medio de intentos
# *	ejecutaRonda(n) #ejecuta la ronda del juego n, y devuelve el número de intentos
# *	imprimeGanador(nmedioIntentos) #A partir del número medio de intentos que se le pasa como parámetro, imprime si el jugador ha ganado, ha empatado o ha perdido.
#
#
# Por último, aquí os dejo un par de ejemplos de ejecución.
#
# <pre>
# Dime cuántas veces quieres jugar a 'Adivina qué color estoy pensando':1
# RONDA  1
# ________________
# Elijo color...
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)rojo
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)amarillo
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)lsakj
# No has elegido un color válido: vuelve a intentarlo
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)verde
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)azul
# Has acertado! Has necesitado  4  intentos
# Lo siento, te ha costado demasiado en adivinar los colores. Has perdido el juego con un número medio de intentos de  4.0
#
#
#
#
# Dime cuántas veces quieres jugar a 'Adivina qué color estoy pensando':-3
# El número debe ser un entero mayor que 0. Vuelve a intentarlo.
# Dime cuántas veces quieres jugar a 'Adivina qué color estoy pensando':2
# RONDA  1
# ________________
# Elijo color...
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)rojo
# Has acertado! Has necesitado  1  intentos
# RONDA  2
# ________________
# Elijo color...
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)amarillo
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)verde
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)azul
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)blanco
# Ohhhh, no has acertado. Inténtalo de nuevo.
# Dime el color que piensas que he elegido (rojo, amarillo, verde, azul, blanco)rojo
# Has acertado! Has necesitado  5  intentos
# Uyyy, casi.. Has empatado con el ordenador con un número medio de intentos de  3.0
#
# </pre>

# %%
#aquí va tu código
