# %% [markdown]
# # Ejercicios de repaso FP

# %%
#Para que se vean las imágenes
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## CÓMO RESOLVER LOS EJERCICIOS
# A la hora de resolver los ejercicios, es muy importante que, sobre todo al principio, antes de poneros a programar dediquéis unos minutos a pensar en lo que os pide el ejercicio y cómo estructurar el código. Para ello os propongo el siguiente proceso:
#
# * Definid, en dos líneas, qué os está pidiendo el ejercicio
# * Identificad las ENTRADAS del programa y de dónde se obtienen.
# * Identificad qué tiene que PROCESAR el programa
# * Identificad qué SALIDA tiene que producir el programa
#
# Sólo una vez que tenéis claro todo esto os debéis poner a programar.
#
# Happy programming!

# %% [markdown]
# # 1.- VARIABLES, OPERANDOS, EXPRESIONES, SENTENCIAS, CONDICIONALES

# %% [markdown]
# ## Ejercicio 1.0.
# Implementa el programa de App Inventor en Python

# %%
#aquí va tu código

# %% [markdown]
# ## Ejercicio 1.1.
# Crea un programa que, dadas las cuatro coordenadas (x1,y1) (x2,y2) de dos puntos cualquiera, te calcule la distancia mínima entre dichos puntos. El programa debe controlar que todas las coordenadas que introduces son enteros. En cuanto el usuario introduzca algo que no sea un entero, el programa debe imprimir un mensaje del tipo "Coordenada Errónea" y acabar.
#
# Pista: Elevar al cuadrado en Python: **
#
# Pista: Raíz cuadrada es igual a elevar a 1/2
#
# Ejemplo de salida:
# <pre>
# Dime x del punto 1: 2
# Dime y del punto 1: 3
# Dime x del punto 2: 5
# Dime y del punto 2: 6
# La longitud de la línea entre los puntos (2,3) y (5,6) es 4.24
# </pre>

# %%
#aquí va tu código

# %% [markdown]
# ## Ejercicio 1.2.
# Escribe un programa de cálculo de salario por semana que, dado el número de horas trabajadas esa semana y una tarifa por hora, calcule el salario de esa semana, teniendo en cuenta que todas las horas trabajadas que excedan de 40 deben pagarse a 1.5 veces la tarifa por hora.
#
# Ejemplo de salida:
# <pre>
# Horas trabajadas: 43
# Tarifa por horas: 10
# Esta semana vas a cobrar  445.0
# </pre>

# %%
# tu código aquí

# %% [markdown]
# ## Ejercicio 1.3.
# Crea un programa que, dada una puntuación numérica entre 0 y 10, muestre la calificación nominal según la siguiente tabla:
#
# * 10: MATRÍCULA DE HONOR
# * 9<=x<10: SOBRESALIENTE
# * 7<=x<9: NOTABLE
# * 6<=x<7: BIEN
# * 5<=x<6: APROBADO
# * x<5: SUSPENSO
#
# Si el número no está en el rango [0..10], el programa debe mostrar un mensaje de error.
#
#
#
# Ejemplos de salida:
# <pre>
# Introduce tu puntuación numérica: 6.3
# BIEN
#
# Introduce tu puntuación numérica: 10
# MATRÍCULA DE HONOR
#
# Introduce tu puntuación numérica: 12
# Puntuación incorrecta
#
# Introduce tu puntuación numérica: 9
# SOBRESALIENTE
# </pre>

# %%
# tu código aquí

# %% [markdown]
# ## Ejercicio 1.4.
# Modifica el programa anterior para que, si el alumno tiene entre 8 y 10, se imprima un mensaje final diciéndole que ha hecho un buen trabajo.

# %%
#tu código aquí

# %% [markdown]
# ## Ejercicio 1.5.
#
# Se dispone de un termómetro para medir con exactitud la temperatura en un determinado lugar. Sin embargo, a nuestros usuarios les basta con saber de manera aproximada si la temperatura se ajusta a los rangos siguientes:
# <pre>
# [-10,10) -> mucho frío
# [10,15)->fresquito
# [15,25)->agradable
# [25,30)->calorcito
# [30,35)->calor
# [35,45)->muucho calor
# </pre>
#
# Crea un programa que simule el comportamiento del termómetro. Para ello, el programa generará una temperatura aleatoria en una escala en el rango [-10,45), y a continuación imprimirá por pantalla un mensaje con la sensación térmica correspondiente a esa temperatura.
#
# Nota: para generar un valor aleatorio entre -10 (incluido, ver corchete) y 45 (sin incluir, ver paréntesis) se tiene que utilizar la función random() de la siguiente manera:
# <pre>
# import random
# #si quiero generar un valor entero: randint incluye los dos límites
# temp=random.randint(-10,44)
# #randrange sin embargo deja fuera el límite superior
# temp=random.randrange(-10,45)
#
# #si lo que quiero es generar un número en coma flotante entre -10 y 45 con un decimal
# temp=round(random.random(),1)*55-10
# </pre>
#
# Puedes ver todas las funciones que ofrece random importando la librería y escribiendo <pre>help(random)</pre>
# Nota por ejemplo cómo la ayuda de la función random.randint(a,b) indica que esta función devuelve un entero aleatorio N tal que a <= N <= b, y como randrange lo genera tal que a<=N<b

# %%
#tu código aquí

# %% [markdown]
# ## Ejercicio 1.6.
# Crea un programa que pida por pantalla el género de una persona y su edad. A continuación, imprimirá en una sola línea su género (masculino, femenino, otro) y si es mayor o menor de edad.
#
# Adición David Oliver: si no se introduce una edad o un género válido, el programa imprimirá un error en pantalla.
#
# Ejemplos de salida:
# <pre>
# Dime tu género (H/M): H
# Dime tu edad: 23
# Eres un hombre mayor de edad
#
# Dime tu género (H/M): M
# Dime tu edad: 15
# Eres una mujer menor de edad
# </pre>

# %%
# tu código aquí

# %% [markdown]
# ## Ejercicio 1.7.
# Una tienda vende pantalones (precio estándar: 20 euros) y camisetas (precio estándar: 10 euros) al por menor y al por mayor. Su política de descuentos es como sigue:
# * Si se compran menos de 5 pantalones, éstos se cobran a su precio estándar
# * En caso de que se compren 5 o más pero menos de 12 , se les descuenta el 15% en cada pantalón
# * Si se compran 12 o más se les descuenta 30% en cada pantalón.
# * Si se compran menos de 10 camisetas, estos se compran a su precio normal
# * Si se compran 10 o más camisetas pero menos de 30, se les descuenta un 10% en cada camiseta.
# * Si se compran 30 o más se les descuenta un 20% en cada camiseta.
#
# Escribe un programa que pida como datos de entrada el número de pantalones y camisetas que se desean comprar. A continuación imprimirá el total a pagar por la compra hecha.
#
# Ejemplos de salida:
# <pre>
# Dime cuántos pantalones quieres comprar: 15
# Dime cuántas camisetas quieres comprar: 10
# Has comprado 15 pantalones a 14.00 euros y 10 camisetas a 9.00 euros. En total te has gastado 300.00 euros.
#
# Dime cuántos pantalones quieres comprar: 2
# Dime cuántas camisetas quieres comprar: 1
# Has comprado 2 pantalones a 20.00 euros y 1 camisetas a 10.00 euros. En total te has gastado 50.00 euros.
#
# </pre>

# %%
# tu código aquí

# %% [markdown]
# ## Ejercicio 1.8.
# Escribe un programa para determinar si un solicitante puede lograr un préstamo. Deberá pedir los siguientes datos para cada solicitante:
#
# *	Nombre
# *	historia crediticia (‘b’buena o ‘m’ mala),
# *	cantidad pedida,
# *	salario anual,
# *	valor de otras propiedades.
#
# El banco sólo considerará a los solicitantes con una historia crediticia buena (b).  De aquellos, sólo aceptara los que tengan más de 6 puntos.  Los puntos se obtienen como sigue:
#
# *	5 puntos si el salario es 50% del préstamo o más.
# *	3 puntos si el salario es por lo menos 25% pero menos de 50% del préstamo.
# *	1 punto si el salario es por lo menos 10% pero menos de 25% del préstamo.
# *	5 puntos si se tiene/n otra/s propiedad/es cuyo valor es de al menos el doble del préstamo.
# *	3 puntos si se tiene/n otra/s propiedad/es cuyo valor es al menos igual al préstamo pero menor del doble.
#
# Ejemplo de salida:
# <pre>
# dime nombre:Cris
# historia crediticia (b/m):b
# Dime la cantidad que deseas:30000
# Dime tu salario anual:35000
# Dime el valor de tus propiedades100000
# Cris , se te ha concedido el préstamo con  10  puntos.
#
# dime nombre:Alfonso
# historia crediticia (b/m):m
# Alfonso , se te ha denegado el préstamo porque tienes un mal historial
#
# dime nombre:Carlos
# historia crediticia (b/m):b
# Dime la cantidad que deseas:30000
# Dime tu salario anual:40000
# Dime el valor de tus propiedades0
# Carlos , se te ha denegado el préstamo con  5  puntos.
#
# </pre>

# %%
#aquí tu código

# %% [markdown]
# ## Ejercicio 1.9a.
# Completad el siguiente código para que el programa resultante diga si el castor está vestido correctamente o no. Las combinaciones correctas están reflejadas en el árbol de decisión mostrado en la figura. Si la combinación no aparece en la figura, asumid que el castor NO está vestido correctamente
# ![Castores](1-9a-dress-code-reducido.png)
#
# Ejemplos de salida:
# <pre>
# ¿Lleva gafas? (s/n)s
# ¿Lleva los pantalones de color azul, marrón u otro? (a/m/o)a
# ¿Lleva la camiseta verde o de otro color (v/o)?o
# ¿Lleva el sombrero de color azul, amarillo o rojo (az,am,r)?am
# El castor está vestido correctamente
#
# ¿Lleva gafas? (s/n)s
# ¿Lleva los pantalones de color azul, marrón u otro? (a/m/o)o
# ¿Lleva la camiseta verde o de otro color (v/o)?o
# ¿Lleva el sombrero de color azul, amarillo o rojo (az,am,r)?r
# El castor está vestido correctamente
#
# ¿Lleva gafas? (s/n)n
# ¿Lleva los pantalones de color azul, marrón u otro? (a/m/o)o
# ¿Lleva la camiseta verde o de otro color (v/o)?o
# ¿Lleva el sombrero de color azul, amarillo o rojo (az,am,r)?az
# El castor está vestido correctamente
#
# ¿Lleva gafas? (s/n)n
# ¿Lleva los pantalones de color azul, marrón u otro? (a/m/o)o
# ¿Lleva la camiseta verde o de otro color (v/o)?o
# ¿Lleva el sombrero de color azul, amarillo o rojo (az,am,r)?am
# El castor NO está vestido correctamente
# </pre>

# %%
#tu código aquí

# %% [markdown]
# ## Ejercicio 1.9b.
# Completad el siguiente código para que el programa resultante diga si el castor está vestido correctamente o no. Las combinaciones correctas están reflejadas en el árbol de decisión mostrado en la figura.
# ![Castores](./1-9b-dress-code.png)
#
# Ejemplos de salida:
# <pre>
# ¿Tiene la cola grande o pequeña? (g/p)g
# ¿Lleva gafas? (s/n)s
# ¿Tiene los dientes grandes o pequeños? (g/p)g
# ¿Lleva los pantalones de color azul, marrón u otro? (a/m/o)a
# ¿Lleva la camiseta verde o de otro color (v/o)?v
# ¿Lleva el sombrero de color azul, amarillo o rojo (az,am,r)?az
# El castor NO está vestido correctamente
#
#
# ¿Tiene la cola grande o pequeña? (g/p)g
# ¿Lleva gafas? (s/n)s
# ¿Tiene los dientes grandes o pequeños? (g/p)g
# ¿Lleva los pantalones de color azul, marrón u otro? (a/m/o)a
# ¿Lleva la camiseta verde o de otro color (v/o)?v
# ¿Lleva el sombrero de color azul, amarillo o rojo (az,am,r)?am
# El castor está vestido correctamente
# </pre>

# %%
# tu código aquí

# %% [markdown]
# ## Ejercicio 1.10.
# Las siguientes tablas resumen los rangos de niveles normales para distintas mediciones de un análisis de sangre.
#
# ![Tablas rangos dependientes de género](1-10-tablasrangosdepgenero.png)
# ![Tablas rangos independientes género](1-10-tablasrangosindepgenero.png)
#
# Por otro lado, disponemos de las siguientes tablas que nos dan los posibles diagnósticos en función de si los valores de hematíes, hemoglobina, hematocrito, volumen corpuscular y hemoglobina corpuscular están por debajo del valor mínimo del rango, dentro del rango normal o por encima de los valores máximos del rango.
# ![Tablas diagnóstico hematíes bajos](1-10-tablasdiagnosticohematiesbajos.png)
# ![Tablas diagnóstico hematíes normales](1-10-tablasdiagnosticohematiesnormales.png)
# ![Tablas diagnóstico hematíes altos](1-10-tablasdiagnosticohematiesaltos.png)
#
#
# Escribe un programa que pida los siguientes valores:
# * categoría (H,M,N)
# * hematíes
# * hemoglobina
# * hematocrito
# * Volumen corpuscular
# * Hemoglobina corpuscular
#
# A partir de ellos, el programa debe imprimir por pantalla el diagnóstico correcto.

# %%
#aquí tu código

# %% [markdown]
# ## Ejercicio 1.11
# Dadas las longitudes en cm de los tres lados de un triángulo, escribid un programa que nos diga si el triángulo es equilátero, isósceles o escaleno.
#
# Ejemplo:
# <pre>
# Dime la longitud del primer lado: 3
# Dime la longitud del segundo lado: 4
# Dime la longitud del tercer lado: 5
# ESCALENO
# </pre>

# %%
#aquí tu código

# %% [markdown]
# ## Ejercicio 1.11 (extensión)
# Completa el programa anterior para que dibuje el triángulo con Turtle.
# Para ello tendrás que calcular los tres ángulos, e ir dirigiendo al puntero para que vaya dibujando cada lado y girando cada ángulo.

# %%
#aquí tu código

# %% [markdown]
# # Ejercicio 1.12
#
# Nos han contado que existe un biomarcador temprano, el CA-125,  del cáncer de ovario, una enfermedad que afecta al 1.5% de la población femenina. El biomarcador está presente en aproximadamente un 80% de las personas enfermos, y en aproximadamente un 4% de personas sin la enfermedad (falsos positivos).
#
# Nos preguntan cuál es la probabilidad de que una persona tenga la enfermedad si ha testado positivo para el biomarcador. ¿Puedes ayudarles?
#
# Nota: para hacerlo, debes crear un programa que implemente el teorema de Bayes:
# www.youtube.com/watch?v=3kD6GyMuf4M
# <pre>
# p(cancer | biomarcador) =(p(biomarcador | cancer)*p(cancer))/p(biomarcador)
#
# Donde:
# p(biomarcador) = p(biomarcador | cancer) ∗ p(cancer) + p(biomarcador | no cancer) ∗ (no cancer)
# </pre>
#
# La solución debe daros:
# Probabilidad (cáncer | tengo biomarcador) =  0.23346303501945526

# %%
# tu código aquí

# %% [markdown]
# # Ejercicio 1.12b
# ¿Qué diferencia hay entre el código anterior y el siguiente código? ¿Cuál es más genérico? ¿Cuál es más comprensible? ¿Cuál es más reutilizable?
# <pre>
# outComeA="biomarcador"
# outComeB="cáncer de ovarios"
# pB=0.015
# pAGivenB=0.8
# pAGivenNotB=0.04
# pNotB = 1.0 - pB
# pA = pAGivenB * pB + pAGivenNotB * pNotB
# pBGivenA = (pAGivenB * pB) / pA
# print('p (%s | %s) = %.2f' % (outcomeB, outcomeA, pBGivenA))
# </pre>

# %% [markdown]
# Aquí va tu comentario

# %% [markdown]
# # Ejercicio 1.13 (https://www.aceptaelreto.com/problem/statement.php?id=112&cat=5)
#
# La Dirección Particular de Tráfico (DPT) está empeñada en hacer que los conductores respeten los límites de velocidad. Sin entrar en si es por razones de seguridad, por ahorrar combustible, o con un mero afán recaudatorio, ahora sabemos que además de los radares fijos tradicionales, están poniendo en funcionamiento los radares de tramo.
#
# Desde un punto de vista formal, estos radares se basan en el teorema de Lagrange (también llamado de valor medio o de Bonnet-Lagrange), que dice que si tienes una función continua en un intervalo cerrado y derivable en el intervalo abierto, entonces algún punto de ese intervalo abierto tendrá derivada instantánea igual a la pendiente media de la curva en el intervalo cerrado.
#
# Aunque asuste a primera vista, la repercusión es sencilla: si hacemos un viaje desde Madrid a Zaragoza y nuestra velocidad media es de 111Km/h, forzosamente en algún punto del camino, nuestra velocidad ha sido de 111Km/h.
#
# Los radares de tramo consisten en colocar dos cámaras en dos puntos alejados de una carretera para poder comprobar cuánto tiempo ha tardado el coche en recorrer ese tramo. Si la velocidad media supera la velocidad máxima permitida, gracias al teorema anterior podremos saber (aunque no le hayamos visto) que en algún punto del trayecto ha superado esa velocidad. Por ejemplo, si colocamos las cámaras separadas 10Km en un tramo cuya velocidad está limitada a 110Km/h, y un coche tarda 5 minutos en ser visto por la segunda cámara, sabremos que su velocidad media ha sido de 120Km/h, y por tanto en algún sitio ha superado el límite de velocidad aunque al pasar por debajo de las dos cámaras el coche fuera a 80Km/h.
#
# Se pedirán al usuario tres números:  el primero será la distancia (en metros) que separan las dos cámaras, el segundo indicará la velocidad máxima permitida en todo ese tramo (en Km/h) y el tercer y último número indicará el número de segundos que ha tardado un coche en recorrer el tramo. Todos esos números serán enteros.
#
#
# Salida
# El programa imprimirá una línea, indicando si el coche debe ser multado o no. En concreto, indicará "OK" si el coche no superó la velocidad máxima, indicará "MULTA" si se superó esa velocidad en menos de un 20% de la velocidad máxima permitida, y "PUNTOS" si la velocidad fue superada en un 20% o más de esa velocidad; en ese caso además de la multa se le quitarán puntos del carnet.

# %%
#aquí va tu código
