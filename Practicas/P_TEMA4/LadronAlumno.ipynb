# %% [markdown]
# # EJERCICIO LADRÓN: TEMA 4
#
# Normas:
# *	El  fichero entregado debe ser este mismo fichero (extensión .ipynb)
# *	Debéis subir el ejercicio al taller de Moodle
# *	No olvidéis indicar al inicio de cada fichero vuestro nombre mediante un comentario Python
# *	El nombre del archivo entregado debe ser LadronXXX.ipynb (donde XXX son vuestras iniciales)

# %% [markdown]
# ## Ejercicio 1
# Vamos a recrear la película de Atrapa al ladrón. Tenemos que crear un programa que simule la persecución entre un policía y un ladrón.
#
# Resulta que el ladrón, que acaba de robar el banco, sale desde la casilla 15 y el policía, que esta en la comisaría, saldrá de la casilla 0. La finalidad del ladrón es subir al avión que está en la casilla 40 sin ser detenido por el policía.
#
# Si al final de la ronda el policía está en la misma casilla que el ladrón o en una casilla superior, el ladrón será detenido.
#
# Si el ladrón consigue llegar al avión sin que lo coja el policía, este será libre.
#
# Resulta que el ladrón va mas lento, pero seguro y su dado solamente saca valores entre 2 y 3. En cambio, el policía va en un coche muy rápido, pero a veces falla, por lo tanto su dado sacará valores entre 0 y 6.
#
# Para que el ejercicio sea más facil, se pide implementar las siguientes funciones:
#
# __Función lanzarDado__: Esta función recibe como parámetro quien tira el dado:
# - Si el tirador es 'ladron' la función tiene que devolver un número entero entre 2 y 3 y mostrar el mensaje "El ladrón ha sacado un [X].
# - Si el tirador es 'policia' la función tiene que devolver un número enero entre 0 y 6 y mostrar el mensaje "El policia ha sacado un [X].
# - Dentro de la función utilizar correctamente la funcion random.randint()
#
# __Función getJugarOtraVez__:    La función pregunta si quieres jugar otra vez y espera una respuesta, que debe ser S o N (en mayúscula o en minúscula, da igual). La función sigue preguntando mientras el usuario no introduzca una entrada válida.
#
# La función devuelve True si el usuario introduce 's' o 'S', y False si introduce 'n' o 'N'.
#
# __Función simularPersecucion__: Esta función se ejecuta en bucle hasta que el ladrón escapa o bien el policía atrapa al ladrón. Para cada ronda:
# - En primer lugar tira el ladrón y se debe llamar correctamente a la funcion lanzarDado con el valor del parámetro correspondiente.
# - En segundo lugar tira el policía y también se debe llamar correctamente a la función lanzarDado con el parámetro correspondiente
# - Finalmente se hace la llamada a mostrarPersecución para visualizar el estado de la partida
#
# La persecución termina si el policía ha cazado al ladrón o bien si el ladrón ha conseguido llegar al avion antes de ser cazado
#  - Si se escapa el ladrón se mostrará "El ladrón ha conseguido escapar"
#  - Si el policía lo caza se mostrará "El policía ha cazado al ladrón"

# %%
import random

def mostrarPersecucion(posicionLadron, posicionPolicia, numRonda):
    if(posicionLadron > posicionPolicia):
        print('Estamos en la ronda ',numRonda,' y el ladron se escapa')
    else:
        print('Estamos en la ronda ', numRonda,' y el policia ha cazado al ladrón')
        
    print('Posición Ladrón ', posicionLadron, '- Posición Policia ', posicionPolicia, '\n')

#implementa aqui la función lanzarDado
    
#Implementa aqui la función getJugarOtraVez

#Acaba de implementar la función simularPersecucion 
def simularPersecucion():
    #Inicializa las variables
    avion = 
    posicionLadron =
    posicionPolicia =
    numRonda =
    
    #Haz el bucle de la persecucion
    
    #Muestra por pantalla el resultado


#programa principal
while True:
    simularPersecucion()
    if getJugarOtraVez()==False:
        break

print('Fin de la simulación')

# %% [markdown]
# # Ejemplo de salida
# <pre>
# El ladrón ha sacado un  3
# El policia ha sacado un  6
# Estamos en la ronda  1  y el ladron se escapa
# Posición Ladrón  13 - Posición Policia  6
#
# El ladrón ha sacado un  3
# El policia ha sacado un  3
# Estamos en la ronda  2  y el ladron se escapa
# Posición Ladrón  16 - Posición Policia  9
#
# El ladrón ha sacado un  2
# El policia ha sacado un  4
# Estamos en la ronda  3  y el ladron se escapa
# Posición Ladrón  18 - Posición Policia  13
#
# El ladrón ha sacado un  3
# El policia ha sacado un  6
# Estamos en la ronda  4  y el ladron se escapa
# Posición Ladrón  21 - Posición Policia  19
#
# El ladrón ha sacado un  3
# El policia ha sacado un  0
# Estamos en la ronda  5  y el ladron se escapa
# Posición Ladrón  24 - Posición Policia  19
#
# El ladrón ha sacado un  2
# El policia ha sacado un  1
# Estamos en la ronda  6  y el ladron se escapa
# Posición Ladrón  26 - Posición Policia  20
#
# El ladrón ha sacado un  3
# El policia ha sacado un  3
# Estamos en la ronda  7  y el ladron se escapa
# Posición Ladrón  29 - Posición Policia  23
#
# El ladrón ha sacado un  3
# El policia ha sacado un  0
# Estamos en la ronda  8  y el ladron se escapa
# Posición Ladrón  32 - Posición Policia  23
#
# El ladrón ha sacado un  3
# El policia ha sacado un  0
# Estamos en la ronda  9  y el ladron se escapa
# Posición Ladrón  35 - Posición Policia  23
#
# El ladrón ha sacado un  3
# El policia ha sacado un  4
# Estamos en la ronda  10  y el ladron se escapa
# Posición Ladrón  38 - Posición Policia  27
#
# El ladrón ha sacado un  3
# El policia ha sacado un  6
# Estamos en la ronda  11  y el ladron se escapa
# Posición Ladrón  41 - Posición Policia  33
#
# El ladrón ha conseguido escapar
# Desea jugar otra vez (s/n)
# </pre>
