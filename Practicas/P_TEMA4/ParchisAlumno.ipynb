# %% [markdown]
# # EJERCICIO PARCHÍS: Repaso de Librerías
# Si se pide corrección colaborativa:
# *	El  fichero entregado debe ser este mismo fichero (extensión .ipynb)
# *	Debéis subir el ejercicio al taller de Moodle
# *	No olvidéis indicar al inicio de cada fichero vuestro nombre mediante un comentario Python
# *	El nombre del archivo entregado debe ser LadronXXX.ipynb (donde XXX son vuestras iniciales)

# %% [markdown]
# Crea un programa que simule el juego del parchís. Estructúralo mediante funciones. Para ello, investiga y haz uso de la librería glparchis

# %%
# instalación manual de la librería
# !pip install glparchis
# Out:
# ...
#      |████████████████████████████████| 3.9 MB 8.7 MB/s
# ...
#   Created wheel for glparchis: filename=glparchis-20181125-py3-none-any.whl size=3336269 sha256=d7e635b4b4d6dc4c7509a55b7ff7af311d53894af63e42725575d98eff49daf6
#   Stored in directory: /root/.cache/pip/wheels/4f/f6/75/b0042a52a441828e8f7d2738726e02a1efda4a8383e5dfb406
# Successfully built glparchis
# ...

# %%
help("glparchis")
#http://turulomio.users.sourceforge.net/doxygen/glparchis/

# %%
#aquí va tu código
